# %% [markdown]
# # Import

# %%
from google import genai

client = genai.Client(api_key="AIzaSyD38NiKR3Nei2ybR-dZyeYgdkAHmVJqjRs")
response = client.models.generate_content(
    model="gemini-2.0-flash", contents="Explain how AI works"
)
print(response.text)
# Out:
# Okay, let's break down how Artificial Intelligence (AI) works in a way that's easy to understand.  Think of AI not as one single thing, but rather as a collection of techniques and approaches that aim to make computers perform tasks that typically require human intelligence.
#
# **The Core Idea: Learning from Data**
#
# At the heart of most AI systems is the idea that computers can *learn* from data, rather than being explicitly programmed to do everything.  This learning allows them to recognize patterns, make predictions, and improve their performance over time.
#
# **Key Concepts and Techniques:**
#
# 1. **Machine Learning (ML):** This is a major subset of AI. It focuses on algorithms that allow computers to learn from data without being explicitly programmed.  Think of it as the computer figuring out the rules itself based on examples.
#
#    *   **Types of Machine Learning:**
#       *   **Supervised Learning:**  The algorithm is trained on a labeled dataset.  This means the data includes both the input and the desired output. For example, you might give an algorithm a bunch of images of cats and dogs, and tell it which images are cats and which are dogs.  The algorithm learns to associate the features of the images with the correct labels.  It's like a student learning from a textbook with answers.
#           *   **Examples:** Image classification (cat vs. dog), spam detection, predicting house prices.
#       *   **Unsupervised Learning:** The algorithm is given unlabeled data. It has to find patterns and structures on its own.  Imagine giving an algorithm a bunch of customer data without telling it anything about the customers. It might be able to group the customers into different segments based on their purchasing behavior.  It's like a detective trying to solve a case with only clues.
#           *   **Examples:** Customer segmentation, anomaly detection, dimensionality reduction.
#       *   **Reinforcement Learning:** The algorithm learns by interacting with an environment and receiving rewards or penalties for its actions.  Think of training a dog. You give the dog a treat when it does something right, and correct it when it does something wrong.  The algorithm learns to maximize its rewards over time.  It's like learning by trial and error.
#           *   **Examples:** Game playing (like AlphaGo), robotics, optimizing resource allocation.
#
# 2.  **Deep Learning (DL):**  This is a subfield of machine learning that uses artificial neural networks with many layers (hence "deep") to analyze data.  These networks are inspired by the structure of the human brain.
#
#     *   **Neural Networks:**  Imagine interconnected nodes (like neurons) arranged in layers.  Each connection between nodes has a weight associated with it.  The network learns by adjusting these weights to produce the correct output.
#     *   **How it works:** Data is fed into the input layer, passes through the hidden layers, and eventually reaches the output layer. Each layer performs computations on the data, transforming it in a way that helps the network learn patterns. The "deep" layers help the network learn increasingly complex features.
#     *   **Examples:** Image recognition, natural language processing, speech recognition. Deep Learning excels at complex tasks that require recognizing subtle patterns in large amounts of data.
#
# 3.  **Natural Language Processing (NLP):**  This area focuses on enabling computers to understand, interpret, and generate human language.
#
#     *   **Tasks:**
#         *   **Text classification:**  Categorizing text (e.g., spam detection, sentiment analysis).
#         *   **Machine translation:** Translating text from one language to another.
#         *   **Question answering:** Answering questions based on a given text.
#         *   **Text summarization:** Generating a concise summary of a longer text.
#     *   **Techniques:** NLP uses techniques from machine learning, deep learning, and linguistics to analyze the structure and meaning of language.
#
# 4.  **Computer Vision:**  This allows computers to "see" and interpret images and videos.
#
#     *   **Tasks:**
#         *   **Object detection:** Identifying objects in an image (e.g., cars, people, trees).
#         *   **Image recognition:** Identifying the content of an image (e.g., a cat, a dog, a landscape).
#         *   **Image segmentation:** Dividing an image into different regions.
#         *   **Facial recognition:** Identifying faces in an image or video.
#     *   **Techniques:**  Computer vision often relies on deep learning models (especially convolutional neural networks) to analyze images and extract features.
#
# 5.  **Robotics:**  AI can be used to control and automate robots.
#
#     *   **Applications:**
#         *   **Manufacturing:** Robots can perform repetitive tasks on assembly lines.
#         *   **Logistics:** Robots can sort and transport packages in warehouses.
#         *   **Healthcare:** Robots can assist with surgery and patient care.
#     *   **Techniques:** AI algorithms can be used for robot navigation, object recognition, and task planning.  Reinforcement learning is often used to train robots to perform complex tasks.
#
# **The AI Development Process (Simplified):**
#
# 1.  **Data Collection:** Gather a large dataset relevant to the problem you're trying to solve.  The quality and quantity of the data are crucial for successful AI.
# 2.  **Data Preprocessing:** Clean and prepare the data for training.  This might involve removing errors, handling missing values, and transforming the data into a suitable format.
# 3.  **Model Selection:** Choose an appropriate AI model (e.g., a specific type of machine learning algorithm) based on the problem and the data.
# 4.  **Model Training:** Feed the data into the model and allow it to learn the underlying patterns.  This involves adjusting the model's parameters to minimize errors.
# 5.  **Model Evaluation:** Test the trained model on a separate dataset to assess its performance.  This helps to identify potential problems such as overfitting (where the model performs well on the training data but poorly on new data).
# 6.  **Deployment:** Deploy the trained model into a real-world application.  This might involve integrating the model into a website, a mobile app, or a robot.
# 7.  **Monitoring and Improvement:** Continuously monitor the model's performance and retrain it with new data to improve its accuracy and adapt to changing conditions.
#
# **Important Considerations:**
#
# *   **Data is Key:** The quality and quantity of data used to train an AI model are critical to its success. Garbage in, garbage out!
# *   **Algorithms are Tools:**  Different algorithms are suited for different tasks.  Choosing the right algorithm is essential.
# *   **Bias:** AI models can inherit biases from the data they are trained on. It's important to be aware of and mitigate these biases to ensure fairness and prevent discrimination.
# *   **Ethics:** AI raises important ethical questions about privacy, security, and the impact on jobs.  It's important to develop and use AI responsibly.
# *   **Computation Power:**  Many AI techniques, especially deep learning, require significant computational resources (e.g., powerful GPUs) to train models efficiently.
#
# **In Summary:**
#
# AI aims to create intelligent systems that can learn from data, solve problems, and automate tasks that typically require human intelligence. It encompasses a wide range of techniques, including machine learning, deep learning, natural language processing, computer vision, and robotics. While AI has made significant progress in recent years, it's still a rapidly evolving field with many challenges and opportunities.

# %%
import google.generativeai as genai
import os

api_key = os.environ.get("GOOGLE_API_KEY")

genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Explain how AI works")

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In[1], line 9
#       6 genai.configure(api_key=api_key)
#       8 model = genai.GenerativeModel('gemini-pro')
# ----> 9 response = model.generate_content("Explain how AI works")
#      11 print(response.text)
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/generativeai/generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.18/envs/livecode_env/lib/python3.9/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.

# %%
import google.generativeai as genai
import os

api_key = os.environ.get("GOOGLE_API_KEY")

if api_key:
    genai.configure(api_key=api_key)

    models = genai.list_models()
    for model in models:
        print(f"Model: {model.name}")
        print(f"Description: {model.description}")
        print(f"Supported Generations: {model.supported_generation_methods}")
        print("-" * 20)
else:
    print("Erro: A variável de ambiente GOOGLE_API_KEY não está definida.")
# Out:
# Model: models/chat-bison-001
# Description: A legacy text-only model optimized for chat conversations
# Supported Generations: ['generateMessage', 'countMessageTokens']
# --------------------
# Model: models/text-bison-001
# Description: A legacy model that understands text and generates text as an output
# Supported Generations: ['generateText', 'countTextTokens', 'createTunedTextModel']
# --------------------
# Model: models/embedding-gecko-001
# Description: Obtain a distributed representation of a text.
# Supported Generations: ['embedText', 'countTextTokens']
# --------------------
# Model: models/gemini-1.0-pro-vision-latest
# Description: The original Gemini 1.0 Pro Vision model version which was optimized for image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. Move to a newer Gemini version.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-pro-vision
# Description: The original Gemini 1.0 Pro Vision model version which was optimized for image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. Move to a newer Gemini version.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-pro-latest
# Description: Alias that points to the most recent production (non-experimental) release of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-pro-001
# Description: Stable version of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens, released in May of 2024.
# Supported Generations: ['generateContent', 'countTokens', 'createCachedContent']
# --------------------
# Model: models/gemini-1.5-pro-002
# Description: Stable version of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens, released in September of 2024.
# Supported Generations: ['generateContent', 'countTokens', 'createCachedContent']
# --------------------
# Model: models/gemini-1.5-pro
# Description: Stable version of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens, released in May of 2024.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-flash-latest
# Description: Alias that points to the most recent production (non-experimental) release of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling across diverse tasks.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-flash-001
# Description: Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling across diverse tasks, released in May of 2024.
# Supported Generations: ['generateContent', 'countTokens', 'createCachedContent']
# --------------------
# Model: models/gemini-1.5-flash-001-tuning
# Description: Version of Gemini 1.5 Flash that supports tuning, our fast and versatile multimodal model for scaling across diverse tasks, released in May of 2024.
# Supported Generations: ['generateContent', 'countTokens', 'createTunedModel']
# --------------------
# Model: models/gemini-1.5-flash
# Description: Alias that points to the most recent stable version of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling across diverse tasks.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-flash-002
# Description: Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling across diverse tasks, released in September of 2024.
# Supported Generations: ['generateContent', 'countTokens', 'createCachedContent']
# --------------------
# Model: models/gemini-1.5-flash-8b
# Description: Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, released in October of 2024.
# Supported Generations: ['createCachedContent', 'generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-flash-8b-001
# Description: Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, released in October of 2024.
# Supported Generations: ['createCachedContent', 'generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-flash-8b-latest
# Description: Alias that points to the most recent production (non-experimental) release of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, released in October of 2024.
# Supported Generations: ['createCachedContent', 'generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-flash-8b-exp-0827
# Description: Experimental release (August 27th, 2024) of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model. Replaced by Gemini-1.5-flash-8b-001 (stable).
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-1.5-flash-8b-exp-0924
# Description: Experimental release (September 24th, 2024) of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model. Replaced by Gemini-1.5-flash-8b-001 (stable).
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-exp
# Description: Gemini 2.0 Flash Experimental
# Supported Generations: ['generateContent', 'countTokens', 'bidiGenerateContent']
# --------------------
# Model: models/gemini-2.0-flash
# Description: Gemini 2.0 Flash
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-001
# Description: Stable version of Gemini 2.0 Flash, our fast and versatile multimodal model for scaling across diverse tasks, released in January of 2025.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-exp-image-generation
# Description: Gemini 2.0 Flash (Image Generation) Experimental
# Supported Generations: ['generateContent', 'countTokens', 'bidiGenerateContent']
# --------------------
# Model: models/gemini-2.0-flash-lite-001
# Description: Stable version of Gemini 2.0 Flash Lite
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-lite
# Description: Gemini 2.0 Flash-Lite
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-lite-preview-02-05
# Description: Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-lite-preview
# Description: Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-pro-exp
# Description: Experimental release (February 5th, 2025) of Gemini 2.0 Pro
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-pro-exp-02-05
# Description: Experimental release (February 5th, 2025) of Gemini 2.0 Pro
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-exp-1206
# Description: Experimental release (February 5th, 2025) of Gemini 2.0 Pro
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-thinking-exp-01-21
# Description: Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-thinking-exp
# Description: Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemini-2.0-flash-thinking-exp-1219
# Description: Gemini 2.0 Flash Thinking Experimental
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/learnlm-1.5-pro-experimental
# Description: Alias that points to the most recent stable version of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 million tokens.
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/gemma-3-27b-it
# Description:
# Supported Generations: ['generateContent', 'countTokens']
# --------------------
# Model: models/embedding-001
# Description: Obtain a distributed representation of a text.
# Supported Generations: ['embedContent']
# --------------------
# Model: models/text-embedding-004
# Description: Obtain a distributed representation of a text.
# Supported Generations: ['embedContent']
# --------------------
# Model: models/gemini-embedding-exp-03-07
# Description: Obtain a distributed representation of a text.
# Supported Generations: ['embedContent']
# --------------------
# Model: models/gemini-embedding-exp
# Description: Obtain a distributed representation of a text.
# Supported Generations: ['embedContent']
# --------------------
# Model: models/aqa
# Description: Model trained to return answers to questions that are grounded in provided sources, along with estimating answerable probability.
# Supported Generations: ['generateAnswer']
# --------------------
# Model: models/imagen-3.0-generate-002
# Description: Vertex served Imagen 3.0 002 model
# Supported Generations: ['predict']
# --------------------

# %%
import google.generativeai as genai
import os

api_key = os.environ.get("GOOGLE_API_KEY")

# if api_key:
#     genai.configure(api_key=api_key)

#     model = genai.GenerativeModel('gemini-1.5-pro') # ou gemini-2.0-flash
#     response = model.generate_content("Explain how AI works")

#     print(response.text)
# else:
#     print("Erro: A variável de ambiente GOOGLE_API_KEY não está definida.")
